# %% [markdown]
# # Flight Delay Analysis

# %% [markdown]
# ## Attributes Info.

# %% [markdown]
# 1.	YEAR: Year of the Flight Trip.
# 2.	MONTH: Month of the Flight Trip.
# 3.	DAY_OF_MONTH: Day of the Flight Trip.
# 4.	DAY_OF_WEEK: Day of week of the Flight Trip.
# 5.	OP_UNIQUE_CARRIER
# 6.	TAIL_NUM: Aircraft Identifier.
# 7.	OP_CARRIER_FL_NUM: Flight Identifier.
# 8.	ORIGIN: Starting Airport.
# 9.	DEST: Destination Airport.
# 10.	CRS_DEP_TIME: Planned Departure Time.
# 11.	DEP_TIME
# 12.	DEP_DELAY: Total Delay on Departure.
# 13.	TAXI_OUT: The time duration elapsed between departure from the origin airport gate and wheels off.
# 14.	TAXI_IN (minutes)
# 15.	CRS_ARR_TIME
# 16.	ARR_TIME (minutes)
# 17.	ARR_DELAY (minutes): A flight is counted as "on time" if it operated less than 15 minutes later the scheduled time shown in the carriers' Computerized Reservations Systems (CRS).
# 18.	CANCELLED: Flight Cancelled (1 = cancelled).
# 19.	CANCELLATION_CODE: Reason for Cancellation of flight: A - Airline/Carrier; B - Weather; C - National Air System; D - Security.
# 20.	DIVERTED: 1 = yes, 0 = no.
# 21.	CRS_ELAPSED_TIME (minutes)
# 22.	ACTUAL_ELAPSED_TIME (minutes)
# 23.	AIR_TIME (minutes): The time duration between wheels_off and wheels_on time.
# 24.	DISTANCE (miles): Distance between two airports.
# 25.	CARRIER_DELAY (minutes): Carrier delay is within the control of the air carrier. Examples of occurrences that may determine carrier delay are: aircraft cleaning, aircraft damage, awaiting the arrival of connecting passengers or crew, baggage, bird strike, cargo loading, catering, computer, outage-carrier equipment, crew legality (pilot or attendant rest), damage by hazardous goods, engineering inspection, fueling, handling disabled passengers, late crew, lavatory servicing, maintenance, over sales, potable water servicing, removal of unruly passenger, slow boarding or seating, stowing carry-on baggage, weight and balance delays.
# 26.	WEATHER_DELAY (minutes): Weather delay is caused by extreme or hazardous weather conditions that are forecasted or manifest themselves on point of departure, enroute, or on point of arrival.
# 27.	NAS_DELAY (minutes): Delay that is within the control of the National Airspace System (NAS) may include: non-extreme weather conditions, airport operations, heavy traffic volume, air traffic control, etc.
# 28.	SECURITY_DELAY (minutes): Security delay is caused by evacuation of a terminal or concourse, re-boarding of aircraft because of security breach, inoperative screening equipment and/or long lines in excess of 29 minutes at screening areas.
# 29.	LATE_AIRCRAFT_DELAY (minutes): Arrival delay at an airport due to the late arrival of the same aircraft at a previous airport. The ripple effect of an earlier delay at downstream airports is referred to as delay propagation.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#data_jan_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\1. January 2018.csv')
#data_feb_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\2. February 2018.csv')
#data_mar_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\3. March 2018.csv')
#data_apr_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\4. April 2018.csv')
#data_may_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\5. May 2018.csv')
#data_jun_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\6. June 2018.csv')
#data_jul_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\7. July 2018.csv')
#data_aug_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\8. August 2018.csv')
#data_sep_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\9. September 2018.csv')
data_oct_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\10. October 2018.csv')
data_nov_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\11. November 2018.csv')
data_dec_18 = pd.read_csv('F:\\Flight_Dataset\\2018\\12. December 2018.csv')
final_data_18 = pd.concat([data_oct_18, data_nov_18, data_dec_18])
pd.set_option('display.max_columns',None)
final_data_18.tail()
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 593837  2018        4     12            13            4  2018-12-13
# 593838  2018        4     12            13            4  2018-12-13
# 593839  2018        4     12            13            4  2018-12-13
# 593840  2018        4     12            13            4  2018-12-13
# 593841  2018        4     12            13            4  2018-12-13
#
#        OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  \
# 593837                DL                  19790         DL   N345NW
# 593838                DL                  19790         DL   N988AT
# 593839                DL                  19790         DL   N328DN
# 593840                DL                  19790         DL   N308DN
# 593841                DL                  19790         DL   N341NW
#
#         OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 593837               2630              10721                1072102
# ...

# %%
final_data_18.shape
# Out:
# (1796121, 58)

# %%
final_data_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1796121 entries, 0 to 593841
# Data columns (total 58 columns):
# YEAR                     int64
# QUARTER                  int64
# MONTH                    int64
# DAY_OF_MONTH             int64
# DAY_OF_WEEK              int64
# FL_DATE                  object
# OP_UNIQUE_CARRIER        object
# OP_CARRIER_AIRLINE_ID    int64
# OP_CARRIER               object
# TAIL_NUM                 object
# OP_CARRIER_FL_NUM        int64
# ORIGIN_AIRPORT_ID        int64
# ORIGIN_AIRPORT_SEQ_ID    int64
# ORIGIN_CITY_MARKET_ID    int64
# ORIGIN                   object
# ORIGIN_CITY_NAME         object
# ORIGIN_STATE_ABR         object
# ORIGIN_STATE_NM          object
# DEST_AIRPORT_ID          int64
# DEST_AIRPORT_SEQ_ID      int64
# DEST_CITY_MARKET_ID      int64
# DEST                     object
# DEST_CITY_NAME           object
# DEST_STATE_ABR           object
# DEST_STATE_NM            object
# CRS_DEP_TIME             int64
# ...

# %%
pd.set_option('display.max_columns',None)
final_data_18_1 = final_data_18.iloc[:, [0, 2, 3, 4, 6, 9, 10, 14, 21, 25, 26, 27, 32, 35, 36, 
                                         37, 38, 43, 44, 45, 46, 47, 48, 50, 52, 53, 54, 55, 56]]
final_data_18_1.head()
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM  \
# 0  2018     10            31            3                UA   N75436
# 1  2018     10            31            3                UA   N27733
# 2  2018     10            31            3                UA   N14219
# 3  2018     10            31            3                UA   N37290
# 4  2018     10            31            3                UA   N406UA
#
#    OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  DEP_TIME  DEP_DELAY  TAXI_OUT  \
# 0               2429    EWR  DEN          1549    1547.0       -2.0      21.0
# 1               2427    ORD  GEG          1951    1946.0       -5.0      17.0
# 2               2426    SNA  DEN          1333    1329.0       -4.0      14.0
# 3               2425    IAD  TPA          1255    1243.0      -12.0      16.0
# 4               2423    SFO  SAN          2140    2135.0       -5.0      15.0
#
#    TAXI_IN  CRS_ARR_TIME  ARR_TIME  ARR_DELAY  CANCELLED CANCELLATION_CODE  \
# ...

# %%
final_data_18_1.shape
# Out:
# (1796121, 29)

# %%
final_data_18_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1796121 entries, 0 to 593841
# Data columns (total 29 columns):
# YEAR                   int64
# MONTH                  int64
# DAY_OF_MONTH           int64
# DAY_OF_WEEK            int64
# OP_UNIQUE_CARRIER      object
# TAIL_NUM               object
# OP_CARRIER_FL_NUM      int64
# ORIGIN                 object
# DEST                   object
# CRS_DEP_TIME           int64
# DEP_TIME               float64
# DEP_DELAY              float64
# TAXI_OUT               float64
# TAXI_IN                float64
# CRS_ARR_TIME           int64
# ARR_TIME               float64
# ARR_DELAY              float64
# CANCELLED              float64
# CANCELLATION_CODE      object
# DIVERTED               float64
# CRS_ELAPSED_TIME       float64
# ACTUAL_ELAPSED_TIME    float64
# AIR_TIME               float64
# DISTANCE               float64
# CARRIER_DELAY          float64
# WEATHER_DELAY          float64
# NAS_DELAY              float64
# ...

# %% [markdown]
# ### Selecting all the rows with cancelled flights and inserting them into their own dataframe

# %%
cancelled_df = final_data_18_1[final_data_18_1['CANCELLED'] == 1]
cancelled_df['TAXI_OUT'].fillna(0, inplace=True) 
cancelled_df.head()
# Out:
#       YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM  \
# 6424  2018     10            28            7                UA      NaN
# 7279  2018     10            23            2                UA      NaN
# 7310  2018     10            23            2                UA      NaN
# 8559  2018     10            25            4                OO   N549CA
# 8560  2018     10            25            4                OO   N549CA
#
#       OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  DEP_TIME  DEP_DELAY  \
# 6424                361    LAS  SFO          1653       NaN        NaN
# 7279               2077    BOS  EWR           600       NaN        NaN
# 7310               2045    EWR  BOS          1330       NaN        NaN
# 8559               3718    EWR  RDU          1710       NaN        NaN
# 8560               3718    RDU  EWR          1455       NaN        NaN
#
#       TAXI_OUT  TAXI_IN  CRS_ARR_TIME  ARR_TIME  ARR_DELAY  CANCELLED  \
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Grouping both dataframes by the DayOfWeek and calculate the percentage of cancelled flights for each day of the week and displaying them in a bar chart

# %%
#import matplotlib.pyplot as plt

#font = {'size'   : 16}
#plt.rc('font', **font)

#days_cancelled = 
#print(cancelled_df['CANCELLED'].groupby(final_data_18_1['DAY_OF_WEEK']))
#days_total = final_data_18_1['CANCELLED'].groupby(final_data_18_1['DAY_OF_WEEK']).count()
#days_frac = np.divide(days_cancelled, days_total)
#x=days_frac.index.values
#week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

#fig, ax = plt.subplots(figsize = (12,6))
#ax.bar(x, days_frac*100, align='center')
#ax.set_ylabel('Percentage of Flights Cancelled')
#ax.set_xticks(x)
#ax.set_xticklabels(rotation = 45)

# %% [markdown]
# #### This shows that early morning and late night flights are slightly more likely to be cancelled

# %%
fig, ax = plt.subplots(figsize = (12,6))

ax.hist([final_data_18_1['CRS_DEP_TIME'], cancelled_df['CRS_DEP_TIME']], normed=1, bins=20, label=['All', 'Cancelled'])

ax.set_xlim(0,2400)

ax.set_xlabel('Scheduled Departure Time (Minutes)')
ax.set_title('Normalized histogram of Scheduled Departure Times')

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (12,6))

ax.hist([final_data_18_1['DAY_OF_MONTH'], cancelled_df['DAY_OF_MONTH']], normed=1, bins=31, label=['All', 'Cancelled'])

ax.set_xlim(0,31)

ax.set_xlabel('Day of Month')
ax.set_title('Normalized histogram of Day of Month')

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (12,6))

ax.hist([final_data_18_1['MONTH'], cancelled_df['MONTH']], normed=1, bins=3, label=['All', 'Cancelled'])

ax.set_xlim(10,12)

ax.set_xlabel('Month')
ax.set_title('Normalized histogram of Months')

plt.legend()
plt.show()

# %% [markdown]
# #### This shows that shorter distance flights are more likely to be cancelled

# %%
fig, ax = plt.subplots(figsize = (12,6))

ax.hist([final_data_18_1['DISTANCE'], cancelled_df['DISTANCE']], normed=1, bins=20, label=['All', 'Cancelled'])

ax.set_xlim(0,3000)
ax.set_xlabel('Flight Distance (Miles)')
ax.set_title('Normalized histogram of Flight Distances')

plt.legend()
plt.show()

# %% [markdown]
# #### This shows that many flights are cancelled before the plane has a chance to taxi-out to the runway

# %%
fig, ax = plt.subplots(figsize = (12,6))

ax.hist([final_data_18_1['TAXI_OUT'], cancelled_df['TAXI_OUT']], normed=1, bins=100, label=['All', 'Cancelled'])

ax.set_xlim(0,100)
ax.set_xlabel('Taxi-Out Time (minutes)')
ax.set_title('Normalized histogram of Taxi-Out times')

plt.legend()
plt.show()

# %% [markdown]
# #### This shows that flights that are cancelled after taxiing-out to the runway have longer taxi-out times on average

# %%
fig, ax = plt.subplots(figsize = (12,6))

x = final_data_18_1['TAXI_OUT'][final_data_18_1['TAXI_OUT' ] > 0]
y = cancelled_df['TAXI_OUT'][cancelled_df['TAXI_OUT' ] > 0]

x_mean = np.mean(x)
y_mean = np.mean(y)

ax.hist([x, y], normed=1, bins=100, label=['All', 'Cancelled'])
ax.plot([x_mean, x_mean],[-0.01,0.07],color='#1f77b4')
ax.plot([y_mean, y_mean],[-0.01,0.07],color='#ff7f0e')

ax.set_xlim(0,100)
ax.set_xlabel('Taxi-Out Time (minutes)')
ax.set_title('Normalized histogram of Taxi-Out times')
plt.ylim(0.00,.35)

plt.legend()
plt.show()

# %% [markdown]
# #### Here we grouped by the carriers and added up all the delay time reasons to get an idea of average delay times and their reasons for all the different carriers

# %%
final_data_18_1['Total_Delay'] = (final_data_18_1['CARRIER_DELAY'] + final_data_18_1['WEATHER_DELAY']
             + final_data_18_1['NAS_DELAY'] + final_data_18_1['SECURITY_DELAY'] + final_data_18_1['LATE_AIRCRAFT_DELAY'])

final_data_18_1_delayed = final_data_18_1[~np.isnan(final_data_18_1['Total_Delay'])]
final_data_18_1['Total_Delay'].fillna(0, inplace=True)
final_data_18_1_delayed.head()

carrier_group = final_data_18_1_delayed['CARRIER_DELAY'].groupby(final_data_18_1_delayed['OP_UNIQUE_CARRIER']).mean()
weather_group = final_data_18_1_delayed['WEATHER_DELAY'].groupby(final_data_18_1_delayed['OP_UNIQUE_CARRIER']).mean()
nas_group = final_data_18_1_delayed['NAS_DELAY'].groupby(final_data_18_1_delayed['OP_UNIQUE_CARRIER']).mean()
security_group = final_data_18_1_delayed['SECURITY_DELAY'].groupby(final_data_18_1_delayed['OP_UNIQUE_CARRIER']).mean()
late_group = final_data_18_1_delayed['LATE_AIRCRAFT_DELAY'].groupby(final_data_18_1_delayed['OP_UNIQUE_CARRIER']).mean()

w_bottom = carrier_group.values
n_bottom = w_bottom + weather_group.values
s_bottom = n_bottom + nas_group.values
l_bottom = s_bottom + security_group.values

x = carrier_group.index.values

fig, ax = plt.subplots(figsize = (12,6))

ax.set_xticks(np.arange(len(x)))
ax.set_xticklabels(x, rotation = 45)
ax.bar(np.arange(len(x)),carrier_group.values, align='center', label='Carrier Delay')
ax.bar(np.arange(len(x)),weather_group.values, align='center', bottom=w_bottom, label='Weather Delay')
ax.bar(np.arange(len(x)),nas_group.values, align='center', bottom=n_bottom, label='NAS Delay')
ax.bar(np.arange(len(x)),security_group.values, align='center', bottom=s_bottom, label='Security Delay')
ax.bar(np.arange(len(x)),late_group.values, align='center', bottom=l_bottom, label='Late Aircraft Delay')

ax.set_xlabel('Aircraft Carrier Code')
ax.set_ylabel('Departure Delay (minutes)')

plt.legend()

# %% [markdown]
# #### Here we grouped by carrier and cancellation code to see how many cancellations each carrier had and the distributions of the reasons for cancellation. We also plot below the total flights from each carrier for normalization purposes.

# %%
cancelled_group = cancelled_df.groupby(['OP_UNIQUE_CARRIER','CANCELLATION_CODE']).size().reindex(fill_value=0.0).unstack()
cg = cancelled_group.fillna(0)

b_bottom = cg.loc[:,'A'].values
c_bottom = b_bottom + cg.loc[:,'B'].values
d_bottom = c_bottom + cg.loc[:,'B'].values

x = cg.loc[:,'A'].index.values

fig, ax = plt.subplots(figsize = (12,6))

ax.set_xticks(np.arange(len(x)))
ax.set_xticklabels(x, rotation = 45)
ax.bar(np.arange(len(x)),cg.loc[:,'A'].values, align='center', label='Carrier Delay')
ax.bar(np.arange(len(x)),cg.loc[:,'B'].values, align='center', bottom=b_bottom, label='Weather Delay')
ax.bar(np.arange(len(x)),cg.loc[:,'C'].values, align='center', bottom=c_bottom, label='NAS Delay')

ax.set_xlabel('Aircraft Carrier Code')
ax.set_ylabel('Number of Cancellations')

plt.legend()
plt.show()

total_flights_per_carrier = final_data_18_1['OP_UNIQUE_CARRIER'].groupby(final_data_18_1['OP_UNIQUE_CARRIER']).count()

fig, ax1 = plt.subplots(figsize = (12,6))

x = total_flights_per_carrier.index.values

ax1.set_xticks(np.arange(len(x)))
ax1.set_xticklabels(x, rotation = 45)
ax1.bar(np.arange(len(x)),total_flights_per_carrier.values, align='center')

ax1.set_xlabel('Aircraft Carrier Code')
ax1.set_ylabel('Total Number of Flights')

plt.show()

# %% [markdown]
# #### This show a summary table for the carriers showing several totals and averages

# %%
carrier_flights = final_data_18_1['OP_UNIQUE_CARRIER'].groupby(final_data_18_1['OP_UNIQUE_CARRIER']).count()
carrier_cancelled = final_data_18_1['CANCELLED'].groupby(final_data_18_1['OP_UNIQUE_CARRIER']).sum()
carrier_delayed = final_data_18_1_delayed['OP_UNIQUE_CARRIER'].groupby(final_data_18_1_delayed['OP_UNIQUE_CARRIER']).count()
carrier_diverted = final_data_18_1['DIVERTED'].groupby(final_data_18_1['OP_UNIQUE_CARRIER']).sum()
carrier_avg_time = final_data_18_1['AIR_TIME'].groupby(final_data_18_1['OP_UNIQUE_CARRIER']).mean()
carrier_avg_dist = final_data_18_1['DISTANCE'].groupby(final_data_18_1['OP_UNIQUE_CARRIER']).mean()
carrier_avg_delay = final_data_18_1['Total_Delay'].groupby(final_data_18_1['OP_UNIQUE_CARRIER']).mean()
carrier_avg_taxiIn = final_data_18_1['TAXI_IN'].groupby(final_data_18_1['OP_UNIQUE_CARRIER']).mean()
carrier_avg_taxiOut = final_data_18_1['TAXI_OUT'].groupby(final_data_18_1['OP_UNIQUE_CARRIER']).mean()
carrier_pct_cancelled = 100*np.divide(carrier_cancelled, carrier_flights)

carrier_names = pd.Series(['Endeavor Air', 'American Airlines','Alaska Airlines','JetBlue Airways',
                          'Delta Airlines', 'Express Jet', 'Frontier Airlines', 'Allegiant Air',
                           'Hawaiian Airlines', 'Envoy Air', 'Spirit Airlines', 'PSA Airlines',
                           'Skywest Airlines','United Airlines','Southwest Airlines', 'Mesa Airlines',
                           'Republic Airways'], index=carrier_flights.index)

summary_table_carrier = pd.concat([carrier_names, carrier_flights, carrier_cancelled, carrier_pct_cancelled,carrier_diverted,
                                   carrier_avg_time, carrier_avg_dist, carrier_avg_delay,
                                   carrier_avg_taxiIn, carrier_avg_taxiOut], axis=1)

summary_table_carrier.columns = ['Carrier Name', 'Total Flights', 'Cancelled Flights', 'Percent Cancelled',
                         'Diverted Flights', 'Average Flight Time (minutes)',
                         'Average Flight Distance (miles)', 'Average Flight Delay (minutes)', 
                         'Average Taxi-In (minutes)', 'Average Taxi-Out (minutes)']


summary_table_carrier
# Out:
#                          Carrier Name  Total Flights  Cancelled Flights  \
# OP_UNIQUE_CARRIER
# 9E                       Endeavor Air          61132              460.0
# AA                  American Airlines         229648             2572.0
# AS                    Alaska Airlines          63083              683.0
# B6                    JetBlue Airways          74862              370.0
# DL                     Delta Airlines         233376              232.0
# EV                        Express Jet          43513             1373.0
# F9                  Frontier Airlines          30371              366.0
# G4                      Allegiant Air          22910              118.0
# HA                  Hawaiian Airlines          21250               41.0
# MQ                          Envoy Air          76336             1874.0
# NK                    Spirit Airlines          43211              160.0
# OH                       PSA Airlines          69796             1818.0
# ...
